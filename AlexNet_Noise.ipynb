# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D,BatchNormalization
 
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(1000)
print(tf.__version__)
# Out:
# 2.4.1

# %%
from tensorflow.python import keras
print(keras.__version__)
# Out:
# 2.4.0

# %%
# (3) Create a sequential model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11),\
 strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Pooling 
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer (Fully Connected Layer)
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096, input_shape=(32, 32, 3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(10))
model.add(BatchNormalization())
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 8, 8, 96)          34944
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 96)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 96)          0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 96)          384
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         614656
# _________________________________________________________________
# activation_10 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 384)         885120
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 384)         1327488
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_13 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_14 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_15 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_16 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1000)              4000
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                10010
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 10)                40
# _________________________________________________________________
# activation_17 (Activation)   (None, 10)                0
# =================================================================
# Total params: 25,730,506
# Trainable params: 25,709,350
# Non-trainable params: 21,156
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics=['accuracy'])

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
#Train-validation-test split

#from sklearn.model_selection import train_test_split
#X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=.3)

X_val, y_val = X_train [:5000], y_train [:5000]
X_train, y_train = X_train[5000:], y_train[5000:]

# %%
X_train.shape
# Out:
# (45000, 32, 32, 3)

# %%
#Dimension of the CIFAR10 dataset

print((X_train.shape,y_train.shape))
print((X_val.shape,y_val.shape))
print((X_test.shape,y_test.shape))
# Out:
# ((45000, 32, 32, 3), (45000, 1))
# ((5000, 32, 32, 3), (5000, 1))
# ((10000, 32, 32, 3), (10000, 1))

# %%
#Onehot Encoding the labels.

from sklearn.utils.multiclass import unique_labels
from tensorflow.keras.utils import to_categorical

# %%
#Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10

y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

# %%
#Verifying the dimension after one hot encoding

print((X_train.shape,y_train.shape))
print((X_val.shape,y_val.shape))
print((X_test.shape,y_test.shape))
# Out:
# ((45000, 32, 32, 3), (45000, 10))
# ((5000, 32, 32, 3), (5000, 10))
# ((10000, 32, 32, 3), (10000, 10))

# %%
def add_noise_and_clip_data(data):
   noise = np.random.normal(loc=0.0, scale=0.1, size=data.shape)
   data = data + noise
   data = np.clip(data, 0., 1.)
   return data

# %%
X_train_noisy = add_noise_and_clip_data(X_train)
# X_test_noisy = add_noise_and_clip_data(X_test)
X_val_noisy = add_noise_and_clip_data(X_val)

# %%
idx = 4
plt.subplot(1,2,1)
plt.imshow(X_train[idx])
plt.title('Original image')
plt.subplot(1,2,2)
plt.imshow(X_train_noisy[idx])
plt.title('Image with noise')
plt.show()

# %%
# from sklearn.utils import shuffle
# x_shuffled, y_shuffled = shuffle(X_train, y_train, random_state=0)
# x_val_shuffled, y_val_shuffled = shuffle(X_val, y_val, random_state=0)

# %%
# import matplotlib.pyplot as plt

# print(y_shuffled[0])
# plt.imshow(x_shuffled[0])
# plt.show()

# print(y_train[0])
# plt.imshow(X_train[0])
# plt.show()

# %%
# Concatenate train original and randomized images
# X_train = np.concatenate((X_train,X_train))
# y_train = np.concatenate((y_train,y_shuffled))
# X_val = np.concatenate((X_val,X_val))
# y_val = np.concatenate((y_val,y_val_shuffled))

# %%
#Image Data Augmentation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1 )

val_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1)

test_generator = ImageDataGenerator(rotation_range=2, horizontal_flip= True,zoom_range=.1)

# %%
#Fitting the augmentation defined above to the data

train_generator.fit(X_train_noisy)
val_generator.fit(X_val_noisy)
# test_generator.fit(X_test)

# %%
#Learning Rate Annealer
from tensorflow.keras.callbacks import EarlyStopping
ES = EarlyStopping(monitor="val_loss", patience=1)
from tensorflow.keras.callbacks import ReduceLROnPlateau
lrr= ReduceLROnPlateau(   monitor='val_accuracy',   factor=.01,   patience=3,  min_lr=1e-5)

# %%
#Defining the parameters

batch_size= 100
epochs=100
learn_rate=.001

# %%
history = model.fit(train_generator.flow(X_train_noisy, y_train, batch_size=32),
                    epochs = 100,
                    batch_size = 64,
                    validation_data = val_generator.flow(X_val_noisy, y_val, batch_size=32),
                    callbacks=[lrr], verbose = 1)
# Out:
# Epoch 1/100
# 1407/1407 [==============================] - 66s 23ms/step - loss: 1.8183 - accuracy: 0.3443 - val_loss: 1.5198 - val_accuracy: 0.4598
# Epoch 2/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.5034 - accuracy: 0.4698 - val_loss: 1.4882 - val_accuracy: 0.4814
# Epoch 3/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.3624 - accuracy: 0.5270 - val_loss: 1.5409 - val_accuracy: 0.4732
# Epoch 4/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.2722 - accuracy: 0.5607 - val_loss: 1.2935 - val_accuracy: 0.5712
# Epoch 5/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.1765 - accuracy: 0.5945 - val_loss: 1.2917 - val_accuracy: 0.5600
# Epoch 6/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.1143 - accuracy: 0.6148 - val_loss: 1.3069 - val_accuracy: 0.5630
# Epoch 7/100
# 1407/1407 [==============================] - 32s 23ms/step - loss: 1.0414 - accuracy: 0.6430 - val_loss: 1.1836 - val_accuracy: 0.5860
# Epoch 8/100
# 1407/1407 [==============================] - 32s 22ms/step - loss: 0.9788 - accuracy: 0.6667 - val_loss: 1.1563 - val_accuracy: 0.6052
# Epoch 9/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.9253 - accuracy: 0.6845 - val_loss: 1.3799 - val_accuracy: 0.5510
# Epoch 10/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.8657 - accuracy: 0.7115 - val_loss: 1.1507 - val_accuracy: 0.6068
# Epoch 11/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.8323 - accuracy: 0.7206 - val_loss: 1.0464 - val_accuracy: 0.6454
# Epoch 12/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.7488 - accuracy: 0.7519 - val_loss: 0.9905 - val_accuracy: 0.6602
# Epoch 13/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.7145 - accuracy: 0.7617 - val_loss: 1.0316 - val_accuracy: 0.6532
# Epoch 14/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.6639 - accuracy: 0.7799 - val_loss: 1.1448 - val_accuracy: 0.6222
# Epoch 15/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.6197 - accuracy: 0.7947 - val_loss: 1.1079 - val_accuracy: 0.6440
# Epoch 16/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.5527 - accuracy: 0.8169 - val_loss: 0.9267 - val_accuracy: 0.6898
# Epoch 17/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.5224 - accuracy: 0.8302 - val_loss: 0.9404 - val_accuracy: 0.6910
# Epoch 18/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.4847 - accuracy: 0.8433 - val_loss: 0.9236 - val_accuracy: 0.6964
# Epoch 19/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.4765 - accuracy: 0.8461 - val_loss: 0.9254 - val_accuracy: 0.6998
# Epoch 20/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4771 - accuracy: 0.8452 - val_loss: 0.9405 - val_accuracy: 0.6912
# Epoch 21/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4590 - accuracy: 0.8524 - val_loss: 0.9228 - val_accuracy: 0.7024
# Epoch 22/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.4534 - accuracy: 0.8568 - val_loss: 0.9453 - val_accuracy: 0.6896
# Epoch 23/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4543 - accuracy: 0.8548 - val_loss: 0.9283 - val_accuracy: 0.6984
# Epoch 24/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4435 - accuracy: 0.8573 - val_loss: 0.9260 - val_accuracy: 0.6968
# Epoch 25/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4389 - accuracy: 0.8596 - val_loss: 0.9389 - val_accuracy: 0.6982
# Epoch 26/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4317 - accuracy: 0.8622 - val_loss: 0.9359 - val_accuracy: 0.7028
# Epoch 27/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4266 - accuracy: 0.8635 - val_loss: 0.9402 - val_accuracy: 0.6990
# Epoch 28/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4196 - accuracy: 0.8662 - val_loss: 0.9449 - val_accuracy: 0.7008
# Epoch 29/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4233 - accuracy: 0.8645 - val_loss: 0.9443 - val_accuracy: 0.7022
# Epoch 30/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4184 - accuracy: 0.8674 - val_loss: 0.9534 - val_accuracy: 0.6996
# Epoch 31/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4112 - accuracy: 0.8687 - val_loss: 0.9408 - val_accuracy: 0.7002
# Epoch 32/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4163 - accuracy: 0.8651 - val_loss: 0.9497 - val_accuracy: 0.6986
# Epoch 33/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4087 - accuracy: 0.8694 - val_loss: 0.9595 - val_accuracy: 0.6972
# Epoch 34/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3942 - accuracy: 0.8736 - val_loss: 0.9514 - val_accuracy: 0.7004
# Epoch 35/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3971 - accuracy: 0.8715 - val_loss: 0.9639 - val_accuracy: 0.6998
# Epoch 36/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3925 - accuracy: 0.8790 - val_loss: 0.9426 - val_accuracy: 0.7012
# Epoch 37/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.4069 - accuracy: 0.8715 - val_loss: 0.9605 - val_accuracy: 0.7054
# Epoch 38/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3876 - accuracy: 0.8780 - val_loss: 0.9477 - val_accuracy: 0.7054
# Epoch 39/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3892 - accuracy: 0.8743 - val_loss: 0.9537 - val_accuracy: 0.7030
# Epoch 40/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3887 - accuracy: 0.8755 - val_loss: 0.9633 - val_accuracy: 0.6976
# Epoch 41/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3880 - accuracy: 0.8773 - val_loss: 0.9541 - val_accuracy: 0.7072
# Epoch 42/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3849 - accuracy: 0.8792 - val_loss: 0.9499 - val_accuracy: 0.7062
# Epoch 43/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3856 - accuracy: 0.8789 - val_loss: 0.9481 - val_accuracy: 0.7050
# Epoch 44/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3779 - accuracy: 0.8784 - val_loss: 0.9561 - val_accuracy: 0.7002
# Epoch 45/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3803 - accuracy: 0.8820 - val_loss: 0.9802 - val_accuracy: 0.7008
# Epoch 46/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3720 - accuracy: 0.8821 - val_loss: 0.9590 - val_accuracy: 0.7058
# Epoch 47/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3684 - accuracy: 0.8829 - val_loss: 0.9541 - val_accuracy: 0.7036
# Epoch 48/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3636 - accuracy: 0.8840 - val_loss: 0.9674 - val_accuracy: 0.7018
# Epoch 49/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3688 - accuracy: 0.8815 - val_loss: 0.9615 - val_accuracy: 0.7034
# Epoch 50/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3590 - accuracy: 0.8887 - val_loss: 0.9641 - val_accuracy: 0.7004
# Epoch 51/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3564 - accuracy: 0.8847 - val_loss: 0.9837 - val_accuracy: 0.6908
# Epoch 52/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3535 - accuracy: 0.8877 - val_loss: 0.9879 - val_accuracy: 0.6954
# Epoch 53/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3533 - accuracy: 0.8885 - val_loss: 0.9826 - val_accuracy: 0.7020
# Epoch 54/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3460 - accuracy: 0.8910 - val_loss: 0.9777 - val_accuracy: 0.7002
# Epoch 55/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3583 - accuracy: 0.8872 - val_loss: 0.9689 - val_accuracy: 0.6992
# Epoch 56/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3584 - accuracy: 0.8856 - val_loss: 0.9683 - val_accuracy: 0.6984
# Epoch 57/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3495 - accuracy: 0.8888 - val_loss: 0.9899 - val_accuracy: 0.6950
# Epoch 58/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.3437 - accuracy: 0.8930 - val_loss: 0.9939 - val_accuracy: 0.6970
# Epoch 59/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3439 - accuracy: 0.8920 - val_loss: 0.9736 - val_accuracy: 0.7030
# Epoch 60/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.3432 - accuracy: 0.8928 - val_loss: 0.9836 - val_accuracy: 0.7046
# Epoch 61/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3355 - accuracy: 0.8944 - val_loss: 0.9624 - val_accuracy: 0.7062
# Epoch 62/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3364 - accuracy: 0.8962 - val_loss: 0.9746 - val_accuracy: 0.7030
# Epoch 63/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.3371 - accuracy: 0.8958 - val_loss: 0.9965 - val_accuracy: 0.6960
# Epoch 64/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3272 - accuracy: 0.8964 - val_loss: 0.9828 - val_accuracy: 0.7002
# Epoch 65/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3342 - accuracy: 0.8946 - val_loss: 1.0013 - val_accuracy: 0.7040
# Epoch 66/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3315 - accuracy: 0.8957 - val_loss: 0.9654 - val_accuracy: 0.7034
# Epoch 67/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3196 - accuracy: 0.8996 - val_loss: 1.0070 - val_accuracy: 0.6940
# Epoch 68/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3239 - accuracy: 0.8967 - val_loss: 0.9905 - val_accuracy: 0.7020
# Epoch 69/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3171 - accuracy: 0.9002 - val_loss: 1.0120 - val_accuracy: 0.6990
# Epoch 70/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3171 - accuracy: 0.9006 - val_loss: 1.0164 - val_accuracy: 0.6986
# Epoch 71/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.3177 - accuracy: 0.9010 - val_loss: 0.9875 - val_accuracy: 0.7014
# Epoch 72/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3219 - accuracy: 0.8978 - val_loss: 1.0113 - val_accuracy: 0.6920
# Epoch 73/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3119 - accuracy: 0.9000 - val_loss: 1.0001 - val_accuracy: 0.6976
# Epoch 74/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3142 - accuracy: 0.9020 - val_loss: 1.0134 - val_accuracy: 0.6978
# Epoch 75/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3191 - accuracy: 0.9007 - val_loss: 0.9964 - val_accuracy: 0.7014
# Epoch 76/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3141 - accuracy: 0.9017 - val_loss: 1.0033 - val_accuracy: 0.6940
# Epoch 77/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3056 - accuracy: 0.9062 - val_loss: 0.9892 - val_accuracy: 0.6994
# Epoch 78/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3056 - accuracy: 0.9050 - val_loss: 1.0012 - val_accuracy: 0.7044
# Epoch 79/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3026 - accuracy: 0.9052 - val_loss: 1.0423 - val_accuracy: 0.6956
# Epoch 80/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3030 - accuracy: 0.9070 - val_loss: 1.0092 - val_accuracy: 0.7058
# Epoch 81/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.3037 - accuracy: 0.9075 - val_loss: 1.0073 - val_accuracy: 0.7030
# Epoch 82/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2990 - accuracy: 0.9081 - val_loss: 0.9884 - val_accuracy: 0.7100
# Epoch 83/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.3020 - accuracy: 0.9071 - val_loss: 1.0225 - val_accuracy: 0.6990
# Epoch 84/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2940 - accuracy: 0.9087 - val_loss: 1.0177 - val_accuracy: 0.7020
# Epoch 85/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2972 - accuracy: 0.9085 - val_loss: 1.0222 - val_accuracy: 0.6992
# Epoch 86/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2932 - accuracy: 0.9102 - val_loss: 1.0105 - val_accuracy: 0.7006
# Epoch 87/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2930 - accuracy: 0.9080 - val_loss: 1.0283 - val_accuracy: 0.6942
# Epoch 88/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.2930 - accuracy: 0.9105 - val_loss: 1.0211 - val_accuracy: 0.6958
# Epoch 89/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2917 - accuracy: 0.9078 - val_loss: 1.0264 - val_accuracy: 0.6932
# Epoch 90/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2890 - accuracy: 0.9098 - val_loss: 1.0129 - val_accuracy: 0.7008
# Epoch 91/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2892 - accuracy: 0.9105 - val_loss: 1.0093 - val_accuracy: 0.6986
# Epoch 92/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2850 - accuracy: 0.9114 - val_loss: 1.0124 - val_accuracy: 0.7010
# Epoch 93/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2821 - accuracy: 0.9124 - val_loss: 1.0228 - val_accuracy: 0.6984
# Epoch 94/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2849 - accuracy: 0.9122 - val_loss: 1.0403 - val_accuracy: 0.6952
# Epoch 95/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2790 - accuracy: 0.9154 - val_loss: 1.0335 - val_accuracy: 0.6960
# Epoch 96/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2770 - accuracy: 0.9149 - val_loss: 1.0453 - val_accuracy: 0.6936
# Epoch 97/100
# 1407/1407 [==============================] - 31s 22ms/step - loss: 0.2736 - accuracy: 0.9154 - val_loss: 1.0310 - val_accuracy: 0.6986
# Epoch 98/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2731 - accuracy: 0.9162 - val_loss: 1.0420 - val_accuracy: 0.6924
# Epoch 99/100
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.2666 - accuracy: 0.9190 - val_loss: 1.0338 - val_accuracy: 0.6998
# Epoch 100/100
# 1407/1407 [==============================] - 30s 22ms/step - loss: 0.2681 - accuracy: 0.9153 - val_loss: 1.0520 - val_accuracy: 0.6984

# %%
# Train the model
# model.fit_generator(X_train, y_train, epochs=1000, batch_size={{choice([10, 32, 64, 128])}}, validation_split=0.2, callbacks=[ES])
# 

# model.fit(train_generator.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch= X_train.shape[0]//batch_size, epochs=epochs, validation_data=val_generator.flow(X_val, y_val, batch_size=batch_size), validation_steps= 25# 0,
      # callbacks=[ES], verbose=1)

# %%
# Pandas and Numpy for data structures and util fucntions
import scipy as sp
import numpy as np
import pandas as pd
from numpy.random import rand
pd.options.display.max_colwidth = 600

# Scikit Imports
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split

# import cnn_utils as utils
# from model_evaluation_utils import get_metrics

# Matplot Imports
import matplotlib.pyplot as plt
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)
# %matplotlib inline

# pandas display data frames as tables
from IPython.display import display, HTML

import warnings
warnings.filterwarnings('ignore')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle('Deep Neural Net Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epochs = list(range(1,100+1))
ax1.plot(epochs, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(epochs)
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epochs, history.history['loss'], label='Train Loss')
ax2.plot(epochs, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(epochs)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
#After successful training, we will visualize its performance.
#Plotting the training and validation loss

# f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

# %%
#Assigning the first subplot to graph training loss and validation loss

# ax[0].plot(model.history.history['loss'],color='b',label='Training Loss')
# ax[0].plot(model.history.history['val_loss'],color='r',label='Validation Loss')

# #Plotting the training accuracy and validation accuracy
# ax[1].plot(model.history.history['accuracy'],color='b',label='Training  Accuracy')
# ax[1].plot(model.history.history['val_accuracy'],color='r',label='Validation Accuracy')

# plt.legend()

# %%
#Defining function for confusion matrix plot

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#Print Confusion matrix

    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Making prediction

y_pred=model.predict_classes(X_test)
y_true=np.argmax(y_test,axis=1)

#Plotting the confusion matrix

from sklearn.metrics import confusion_matrix
confusion_mtx=confusion_matrix(y_true,y_pred)

class_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Plotting non-normalized confusion matrix

plot_confusion_matrix(y_true, y_pred, classes = class_names,title = 'Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %%
# Plotting normalized confusion matrix

plot_confusion_matrix(y_true, y_pred, classes=class_names, normalize=True, title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix

# %%
#Classification accuracy

from sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_true, y_pred)
print('Accuracy Score = ', acc_score)
# Out:
# Accuracy Score =  0.7033
