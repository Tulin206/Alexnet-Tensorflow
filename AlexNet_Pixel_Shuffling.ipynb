# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D,BatchNormalization
 
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(1000)
print(tf.__version__)
# Out:
# 2.4.1

# %%
from tensorflow.python import keras
print(keras.__version__)
# Out:
# 2.4.0

# %%
# (3) Create a sequential model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11),\
 strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Pooling 
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer (Fully Connected Layer)
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096, input_shape=(32, 32, 3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(10))
model.add(BatchNormalization())
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 8, 8, 96)          34944
# _________________________________________________________________
# activation_18 (Activation)   (None, 8, 8, 96)          0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 96)          0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 4, 4, 96)          384
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 256)         614656
# _________________________________________________________________
# activation_19 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 384)         885120
# _________________________________________________________________
# activation_20 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 384)         1327488
# _________________________________________________________________
# activation_21 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_22 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_23 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_24 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_10 (Dense)             (None, 1000)              4097000
# _________________________________________________________________
# activation_25 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 1000)              4000
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                10010
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 10)                40
# _________________________________________________________________
# activation_26 (Activation)   (None, 10)                0
# =================================================================
# Total params: 25,730,506
# Trainable params: 25,709,350
# Non-trainable params: 21,156
# _________________________________________________________________

# %%
# COmpiling the model
model.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics=['accuracy'])

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
#Train-validation-test split

#from sklearn.model_selection import train_test_split
#X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=.3)

X_val, y_val = X_train [:5000], y_train [:5000]
X_train, y_train = X_train[5000:], y_train[5000:]

# %%
X_train.shape
# Out:
# (45000, 32, 32, 3)

# %%
#Dimension of the CIFAR10 dataset

print((X_train.shape,y_train.shape))
print((X_val.shape,y_val.shape))
print((X_test.shape,y_test.shape))
# Out:
# ((45000, 32, 32, 3), (45000, 1))
# ((5000, 32, 32, 3), (5000, 1))
# ((10000, 32, 32, 3), (10000, 1))

# %%
#Onehot Encoding the labels.

from sklearn.utils.multiclass import unique_labels
from tensorflow.keras.utils import to_categorical

# %%
#Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10

y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

# %%
#Verifying the dimension after one hot encoding

print((X_train.shape,y_train.shape))
print((X_val.shape,y_val.shape))
print((X_test.shape,y_test.shape))
# Out:
# ((45000, 32, 32, 3), (45000, 10))
# ((5000, 32, 32, 3), (5000, 10))
# ((10000, 32, 32, 3), (10000, 10))

# %%
# Create a function for pixel shuffling

def shuffle_image_pixel(rgbImg):
    rndImg2 = np.reshape(rgbImg, (rgbImg.shape[0] * rgbImg.shape[1], rgbImg.shape[2]))
    np.random.shuffle(rndImg2)
    rdmImg = np.reshape(rndImg2, rgbImg.shape)

    return rdmImg

# %%
# randomize pixel for training data
for i in range(len(X_train)):
    X_train[i] = shuffle_image_pixel(X_train[i])

# randomize pixel for validation data
for i in range(len(X_val)):
    X_val[i] = shuffle_image_pixel(X_val[i])

# randomize pixel for test data
for i in range(len(X_test)):
    X_test[i] = shuffle_image_pixel(X_test[i])

# %%
#Image Data Augmentation

# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# train_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1 )

# val_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1)

# test_generator = ImageDataGenerator(rotation_range=2, horizontal_flip= True,zoom_range=.1)

# %%
#Fitting the augmentation defined above to the data

# train_generator.fit(X_train)
# val_generator.fit(X_val)
# test_generator.fit(X_test)

# %%
#Learning Rate Annealer
from tensorflow.keras.callbacks import EarlyStopping
ES = EarlyStopping(monitor="val_loss", patience=1)
from tensorflow.keras.callbacks import ReduceLROnPlateau
lrr= ReduceLROnPlateau(   monitor='val_accuracy',   factor=.01,   patience=3,  min_lr=1e-5)

# %%
#Defining the parameters

batch_size= 100
epochs=100
learn_rate=.001

# %%
history = model.fit(X_train, y_train,validation_data = (X_val, y_val),
                    epochs = 100,
                    batch_size = 64,
                    callbacks=[lrr], verbose = 1)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 13s 17ms/step - loss: 2.0783 - accuracy: 0.2297 - val_loss: 2.2341 - val_accuracy: 0.2194
# Epoch 2/100
# 704/704 [==============================] - 11s 16ms/step - loss: 1.9809 - accuracy: 0.2598 - val_loss: 3.2603 - val_accuracy: 0.1740
# Epoch 3/100
# 704/704 [==============================] - 11s 16ms/step - loss: 1.9523 - accuracy: 0.2770 - val_loss: 2.0695 - val_accuracy: 0.2284
# Epoch 4/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.9428 - accuracy: 0.2793 - val_loss: 3.0927 - val_accuracy: 0.1460
# Epoch 5/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.9380 - accuracy: 0.2803 - val_loss: 2.5931 - val_accuracy: 0.1990
# Epoch 6/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.9121 - accuracy: 0.2887 - val_loss: 2.8459 - val_accuracy: 0.1750
# Epoch 7/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.8744 - accuracy: 0.3062 - val_loss: 1.8899 - val_accuracy: 0.2996
# Epoch 8/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.8621 - accuracy: 0.3082 - val_loss: 1.9003 - val_accuracy: 0.2972
# Epoch 9/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8563 - accuracy: 0.3133 - val_loss: 1.9026 - val_accuracy: 0.3022
# Epoch 10/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8550 - accuracy: 0.3163 - val_loss: 1.9019 - val_accuracy: 0.2982
# Epoch 11/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8479 - accuracy: 0.3195 - val_loss: 1.9074 - val_accuracy: 0.3020
# Epoch 12/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8449 - accuracy: 0.3193 - val_loss: 1.8977 - val_accuracy: 0.3000
# Epoch 13/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8402 - accuracy: 0.3210 - val_loss: 1.9029 - val_accuracy: 0.3022
# Epoch 14/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8479 - accuracy: 0.3168 - val_loss: 1.9030 - val_accuracy: 0.2982
# Epoch 15/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8372 - accuracy: 0.3195 - val_loss: 1.8959 - val_accuracy: 0.2996
# Epoch 16/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8373 - accuracy: 0.3251 - val_loss: 1.9008 - val_accuracy: 0.2998
# Epoch 17/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8364 - accuracy: 0.3217 - val_loss: 1.8962 - val_accuracy: 0.2992
# Epoch 18/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8283 - accuracy: 0.3252 - val_loss: 1.9113 - val_accuracy: 0.3024
# Epoch 19/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8362 - accuracy: 0.3206 - val_loss: 1.9154 - val_accuracy: 0.3000
# Epoch 20/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8306 - accuracy: 0.3244 - val_loss: 1.9185 - val_accuracy: 0.3008
# Epoch 21/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8301 - accuracy: 0.3263 - val_loss: 1.9127 - val_accuracy: 0.3004
# Epoch 22/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8277 - accuracy: 0.3264 - val_loss: 1.9079 - val_accuracy: 0.2986
# Epoch 23/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8260 - accuracy: 0.3249 - val_loss: 1.9122 - val_accuracy: 0.2994
# Epoch 24/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8225 - accuracy: 0.3275 - val_loss: 1.9245 - val_accuracy: 0.2988
# Epoch 25/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8270 - accuracy: 0.3296 - val_loss: 1.9272 - val_accuracy: 0.2988
# Epoch 26/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8227 - accuracy: 0.3325 - val_loss: 1.9175 - val_accuracy: 0.2994
# Epoch 27/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8208 - accuracy: 0.3295 - val_loss: 1.9225 - val_accuracy: 0.2986
# Epoch 28/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8157 - accuracy: 0.3300 - val_loss: 1.9271 - val_accuracy: 0.2982
# Epoch 29/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8096 - accuracy: 0.3331 - val_loss: 1.9293 - val_accuracy: 0.2992
# Epoch 30/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8103 - accuracy: 0.3348 - val_loss: 1.9153 - val_accuracy: 0.2986
# Epoch 31/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8128 - accuracy: 0.3333 - val_loss: 1.9321 - val_accuracy: 0.2940
# Epoch 32/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8159 - accuracy: 0.3300 - val_loss: 1.9284 - val_accuracy: 0.2980
# Epoch 33/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8016 - accuracy: 0.3363 - val_loss: 1.9387 - val_accuracy: 0.2922
# Epoch 34/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8046 - accuracy: 0.3365 - val_loss: 1.9410 - val_accuracy: 0.2956
# Epoch 35/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8008 - accuracy: 0.3381 - val_loss: 1.9311 - val_accuracy: 0.2948
# Epoch 36/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.8019 - accuracy: 0.3393 - val_loss: 1.9492 - val_accuracy: 0.2938
# Epoch 37/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7968 - accuracy: 0.3396 - val_loss: 1.9406 - val_accuracy: 0.2950
# Epoch 38/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7920 - accuracy: 0.3451 - val_loss: 1.9230 - val_accuracy: 0.2932
# Epoch 39/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7932 - accuracy: 0.3406 - val_loss: 1.9413 - val_accuracy: 0.2962
# Epoch 40/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7914 - accuracy: 0.3423 - val_loss: 1.9609 - val_accuracy: 0.2950
# Epoch 41/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7916 - accuracy: 0.3459 - val_loss: 1.9467 - val_accuracy: 0.2954
# Epoch 42/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7869 - accuracy: 0.3427 - val_loss: 1.9370 - val_accuracy: 0.2942
# Epoch 43/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7818 - accuracy: 0.3478 - val_loss: 1.9476 - val_accuracy: 0.2958
# Epoch 44/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7793 - accuracy: 0.3498 - val_loss: 1.9504 - val_accuracy: 0.2924
# Epoch 45/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7820 - accuracy: 0.3496 - val_loss: 1.9396 - val_accuracy: 0.2938
# Epoch 46/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7721 - accuracy: 0.3507 - val_loss: 1.9669 - val_accuracy: 0.2920
# Epoch 47/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7684 - accuracy: 0.3498 - val_loss: 1.9700 - val_accuracy: 0.2932
# Epoch 48/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7725 - accuracy: 0.3506 - val_loss: 1.9679 - val_accuracy: 0.2906
# Epoch 49/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7718 - accuracy: 0.3519 - val_loss: 1.9725 - val_accuracy: 0.2886
# Epoch 50/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7612 - accuracy: 0.3552 - val_loss: 1.9643 - val_accuracy: 0.2890
# Epoch 51/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7606 - accuracy: 0.3578 - val_loss: 1.9629 - val_accuracy: 0.2908
# Epoch 52/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7519 - accuracy: 0.3621 - val_loss: 1.9739 - val_accuracy: 0.2912
# Epoch 53/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7495 - accuracy: 0.3595 - val_loss: 1.9821 - val_accuracy: 0.2898
# Epoch 54/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7496 - accuracy: 0.3624 - val_loss: 1.9796 - val_accuracy: 0.2920
# Epoch 55/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7446 - accuracy: 0.3633 - val_loss: 1.9945 - val_accuracy: 0.2882
# Epoch 56/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7379 - accuracy: 0.3689 - val_loss: 1.9769 - val_accuracy: 0.2896
# Epoch 57/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7373 - accuracy: 0.3638 - val_loss: 1.9796 - val_accuracy: 0.2894
# Epoch 58/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7331 - accuracy: 0.3683 - val_loss: 1.9940 - val_accuracy: 0.2874
# Epoch 59/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7281 - accuracy: 0.3703 - val_loss: 1.9999 - val_accuracy: 0.2880
# Epoch 60/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7232 - accuracy: 0.3719 - val_loss: 1.9927 - val_accuracy: 0.2834
# Epoch 61/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7272 - accuracy: 0.3676 - val_loss: 1.9951 - val_accuracy: 0.2844
# Epoch 62/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7148 - accuracy: 0.3748 - val_loss: 2.0094 - val_accuracy: 0.2838
# Epoch 63/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.7124 - accuracy: 0.3774 - val_loss: 2.0263 - val_accuracy: 0.2828
# Epoch 64/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6975 - accuracy: 0.3850 - val_loss: 2.0243 - val_accuracy: 0.2828
# Epoch 65/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6914 - accuracy: 0.3881 - val_loss: 2.0502 - val_accuracy: 0.2814
# Epoch 66/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6875 - accuracy: 0.3841 - val_loss: 2.0346 - val_accuracy: 0.2782
# Epoch 67/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6839 - accuracy: 0.3863 - val_loss: 2.0319 - val_accuracy: 0.2812
# Epoch 68/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6828 - accuracy: 0.3901 - val_loss: 2.0524 - val_accuracy: 0.2782
# Epoch 69/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6703 - accuracy: 0.3943 - val_loss: 2.0473 - val_accuracy: 0.2762
# Epoch 70/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6667 - accuracy: 0.4020 - val_loss: 2.0550 - val_accuracy: 0.2798
# Epoch 71/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6561 - accuracy: 0.4017 - val_loss: 2.0671 - val_accuracy: 0.2758
# Epoch 72/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6453 - accuracy: 0.4045 - val_loss: 2.0674 - val_accuracy: 0.2818
# Epoch 73/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6354 - accuracy: 0.4103 - val_loss: 2.1028 - val_accuracy: 0.2740
# Epoch 74/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6262 - accuracy: 0.4138 - val_loss: 2.0970 - val_accuracy: 0.2796
# Epoch 75/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6236 - accuracy: 0.4163 - val_loss: 2.0727 - val_accuracy: 0.2758
# Epoch 76/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6174 - accuracy: 0.4175 - val_loss: 2.1080 - val_accuracy: 0.2740
# Epoch 77/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.6128 - accuracy: 0.4247 - val_loss: 2.1055 - val_accuracy: 0.2754
# Epoch 78/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5981 - accuracy: 0.4255 - val_loss: 2.1090 - val_accuracy: 0.2740
# Epoch 79/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5944 - accuracy: 0.4293 - val_loss: 2.1376 - val_accuracy: 0.2736
# Epoch 80/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5805 - accuracy: 0.4321 - val_loss: 2.1482 - val_accuracy: 0.2680
# Epoch 81/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5777 - accuracy: 0.4357 - val_loss: 2.1561 - val_accuracy: 0.2726
# Epoch 82/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5668 - accuracy: 0.4391 - val_loss: 2.1317 - val_accuracy: 0.2660
# Epoch 83/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5591 - accuracy: 0.4407 - val_loss: 2.1370 - val_accuracy: 0.2696
# Epoch 84/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5494 - accuracy: 0.4486 - val_loss: 2.1441 - val_accuracy: 0.2726
# Epoch 85/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5406 - accuracy: 0.4488 - val_loss: 2.1968 - val_accuracy: 0.2608
# Epoch 86/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5309 - accuracy: 0.4522 - val_loss: 2.1661 - val_accuracy: 0.2702
# Epoch 87/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5209 - accuracy: 0.4547 - val_loss: 2.1977 - val_accuracy: 0.2698
# Epoch 88/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5179 - accuracy: 0.4590 - val_loss: 2.2125 - val_accuracy: 0.2706
# Epoch 89/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5010 - accuracy: 0.4631 - val_loss: 2.2103 - val_accuracy: 0.2664
# Epoch 90/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.5051 - accuracy: 0.4610 - val_loss: 2.2223 - val_accuracy: 0.2666
# Epoch 91/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4857 - accuracy: 0.4705 - val_loss: 2.2396 - val_accuracy: 0.2666
# Epoch 92/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4863 - accuracy: 0.4724 - val_loss: 2.2573 - val_accuracy: 0.2678
# Epoch 93/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4778 - accuracy: 0.4767 - val_loss: 2.2433 - val_accuracy: 0.2618
# Epoch 94/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4578 - accuracy: 0.4782 - val_loss: 2.2605 - val_accuracy: 0.2648
# Epoch 95/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4538 - accuracy: 0.4810 - val_loss: 2.2503 - val_accuracy: 0.2626
# Epoch 96/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4459 - accuracy: 0.4839 - val_loss: 2.2442 - val_accuracy: 0.2664
# Epoch 97/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4371 - accuracy: 0.4889 - val_loss: 2.2971 - val_accuracy: 0.2634
# Epoch 98/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4351 - accuracy: 0.4932 - val_loss: 2.2691 - val_accuracy: 0.2688
# Epoch 99/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4256 - accuracy: 0.4939 - val_loss: 2.2873 - val_accuracy: 0.2638
# Epoch 100/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.4091 - accuracy: 0.5011 - val_loss: 2.3106 - val_accuracy: 0.2648

# %%
# history = model.fit(train_generator.flow(X_train, y_train, batch_size=32),
#                     epochs = 100,
#                     batch_size = 64,
#                     validation_data = val_generator.flow(X_val, y_val, batch_size=32),
#                     callbacks=[lrr], verbose = 1)

# %%
# Train the model
# model.fit_generator(X_train, y_train, epochs=1000, batch_size={{choice([10, 32, 64, 128])}}, validation_split=0.2, callbacks=[ES])
# 

# model.fit(train_generator.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch= X_train.shape[0]//batch_size, epochs=epochs, validation_data=val_generator.flow(X_val, y_val, batch_size=batch_size), validation_steps= 25# 0,
      # callbacks=[ES], verbose=1)

# %%
# Pandas and Numpy for data structures and util fucntions
import scipy as sp
import numpy as np
import pandas as pd
from numpy.random import rand
pd.options.display.max_colwidth = 600

# Scikit Imports
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split

# import cnn_utils as utils
# from model_evaluation_utils import get_metrics

# Matplot Imports
import matplotlib.pyplot as plt
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)
# %matplotlib inline

# pandas display data frames as tables
from IPython.display import display, HTML

import warnings
warnings.filterwarnings('ignore')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle('Deep Neural Net Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epochs = list(range(1,100+1))
ax1.plot(epochs, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(epochs)
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epochs, history.history['loss'], label='Train Loss')
ax2.plot(epochs, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(epochs)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
#After successful training, we will visualize its performance.
#Plotting the training and validation loss

# f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

# %%
#Assigning the first subplot to graph training loss and validation loss

# ax[0].plot(model.history.history['loss'],color='b',label='Training Loss')
# ax[0].plot(model.history.history['val_loss'],color='r',label='Validation Loss')

# #Plotting the training accuracy and validation accuracy
# ax[1].plot(model.history.history['accuracy'],color='b',label='Training  Accuracy')
# ax[1].plot(model.history.history['val_accuracy'],color='r',label='Validation Accuracy')

# plt.legend()

# %%
#Defining function for confusion matrix plot

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#Print Confusion matrix

    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Making prediction

y_pred=model.predict_classes(X_test)
y_true=np.argmax(y_test,axis=1)

#Plotting the confusion matrix

from sklearn.metrics import confusion_matrix
confusion_mtx=confusion_matrix(y_true,y_pred)

class_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Plotting non-normalized confusion matrix

plot_confusion_matrix(y_true, y_pred, classes = class_names,title = 'Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %%
# Plotting normalized confusion matrix

plot_confusion_matrix(y_true, y_pred, classes=class_names, normalize=True, title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix

# %%
#Classification accuracy

from sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_true, y_pred)
print('Accuracy Score = ', acc_score)
# Out:
# Accuracy Score =  0.2561
